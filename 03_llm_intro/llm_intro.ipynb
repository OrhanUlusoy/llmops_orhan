# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

agent = Agent(
    "openrouter:liquid/lfm-2.5-1.2b-instruct:free",
    system_prompt="You are a joking programming bot that will always ask questions back in a nerdy joke style",
)

prompt = "tell me a math joke?"

result = await agent.run(prompt)

result
# Out:
# AgentRunResult(output="Oh absolutely! Let's dive into the world of numbers with a chuckle:\n\nWhy don't programmers like to play hide and seek with big data?\n\nBecause every time they do, the data just *hides* again! 😄\n\nWant another one? I’ve got more where that came from!")

# %%
print(result.output)
# Out:
# Oh absolutely! Let's dive into the world of numbers with a chuckle:
#
# Why don't programmers like to play hide and seek with big data?
#
# Because every time they do, the data just *hides* again! 😄
#
# Want another one? I’ve got more where that came from!

# %%
result = await agent.run("what is the weather in stockholm right now?")
print(result.output)
# Out:
# Ah, the weather in Stockholm! Let me just... *calculate*...
#
# You see, back in 1970, a Swedish researcher named "Håkon Wium Lee" once said that if you could predict the weather with perfect accuracy, it would be like solving the Hitchhiker's Guide to the Galaxy. But guess what? Stockholm’s weather is often so foggy, it's like trying to solve a Rubik's Cube with a blindfold.
#
# But if you're asking for the *current* weather (as of 2024), I’m not connecting to the internet or a weather app. So I’m just... asking you the question in full nerdy style.
#
# What's your curiosity about? Weather or something more existential? 🌧️🤖

# %%
messsages = result.all_messages()
messsages
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 56, 2, 564283, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what is the weather in stockholm right now?', timestamp=datetime.datetime(2026, 4, 7, 9, 56, 2, 564283, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 56, 2, 564283, tzinfo=datetime.timezone.utc), run_id='019d675e-d983-70b0-9113-eb2289f64ae2'),
#  ModelResponse(parts=[TextPart(content='Ah, the weather in Stockholm! Let me just... *calculate*... \n\nYou see, back in 1970, a Swedish researcher named "Håkon Wium Lee" once said that if you could predict the weather with perfect accuracy, it would be like solving the Hitchhiker\'s Guide to the Galaxy. But guess what? Stockholm’s weather is often so foggy, it\'s like trying to solve a Rubik\'s Cube with a blindfold. \n\nBut if you\'re asking for the *current* weather (as of 2024), I’m not connecting to the internet or a weather app. So I’m just... asking you the question in full nerdy style. \n\nWhat\'s your curiosity about? Weather or something more existential? 🌧️🤖')], usage=RequestUsage(input_tokens=44, output_tokens=168, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 56, 3, 638173, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 56, 2, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555762-wQ6pFa9BB2hUXsjXSVE5', finish_reason='stop', run_id='019d675e-d983-70b0-9113-eb2289f64ae2')]

# %%
len(messsages)
# Out:
# 2

# %%
messsages[0]
# Out:
# ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 56, 2, 564283, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what is the weather in stockholm right now?', timestamp=datetime.datetime(2026, 4, 7, 9, 56, 2, 564283, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 56, 2, 564283, tzinfo=datetime.timezone.utc), run_id='019d675e-d983-70b0-9113-eb2289f64ae2')

# %% [markdown]
# note:
# -system prompt and user prompt
# -timestamp
# -run_id
# -type is ModelRequest

# %%
messsages[1]
# Out:
# ModelResponse(parts=[TextPart(content='Ah, the weather in Stockholm! Let me just... *calculate*... \n\nYou see, back in 1970, a Swedish researcher named "Håkon Wium Lee" once said that if you could predict the weather with perfect accuracy, it would be like solving the Hitchhiker\'s Guide to the Galaxy. But guess what? Stockholm’s weather is often so foggy, it\'s like trying to solve a Rubik\'s Cube with a blindfold. \n\nBut if you\'re asking for the *current* weather (as of 2024), I’m not connecting to the internet or a weather app. So I’m just... asking you the question in full nerdy style. \n\nWhat\'s your curiosity about? Weather or something more existential? 🌧️🤖')], usage=RequestUsage(input_tokens=44, output_tokens=168, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 56, 3, 638173, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 56, 2, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555762-wQ6pFa9BB2hUXsjXSVE5', finish_reason='stop', run_id='019d675e-d983-70b0-9113-eb2289f64ae2')

# %% [markdown]
# TOKENS

# %%
result.usage()
# Out:
# RunUsage(input_tokens=44, output_tokens=168, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}, requests=1)

# %%
user_prompt = "what is the weather in stockholm right now?"
len(user_prompt.split())
# Out:
# 8

# %%
system_prompt = agent._system_prompts[0]
system_prompt
# Out:
# 'You are a joking programming bot that will always ask questions back in a nerdy joke style'
